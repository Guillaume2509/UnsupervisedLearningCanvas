# %% [markdown]
# Importer les jeux de données du canva

# %%
import pandas as pd
filename1 = r"C:\Users\Guillaume\Desktop\Portfolio\Jeux de données\Grains\seeds-width-vs-length.csv"
grains = pd.read_csv(filename1, sep=',', header=None, index_col=False)

# %% [markdown]
# Illustrer et imprimer la corrélation entre la largeur et la longueur d'un grain de riz

# %%
# Perform the necessary imports
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# Assign the 0th column of grains: width
width = grains.iloc[:,0]

# Assign the 1st column of grains: length
length = grains.iloc[:,1]

# Scatter plot width vs length
plt.scatter(width, length)
plt.axis('equal')
plt.show()

# Calculate the Pearson correlation
correlation, pvalue = pearsonr(width, length)

# Display the correlation
print("The correlation between width and length is " + str(correlation))
# Out:
# The correlation between width and length is 0.8604149377143462

# %% [markdown]
# Déterminer sur un graphique, à l'aide d'une flèche, dans quelle direction varient le plus les données

# %%
# Importing PCA
from sklearn.decomposition import PCA

# Make a scatter plot of the untransformed points
plt.scatter(grains.iloc[:,0], grains.iloc[:,1])

# Create a PCA instance: model
model = PCA()

# Fit model to points
model.fit(grains)

# Get the mean of the grain samples: mean
mean = model.mean_

# Get the first principal component: first_pc
first_pc = model.components_[0,:]

# Plot first_pc as an arrow, starting at mean
plt.arrow(mean[0], mean[1], first_pc[0], first_pc[1], color='red', width=0.01)

# Keep axes on same scale
plt.axis('equal')
plt.show()

# %% [markdown]
# Représenter sur un graphique à barres, avec le jeu des poissons

# %%
# Import the fishes dataset
filename2 = r"C:\Users\Guillaume\Desktop\Portfolio\Jeux de données\fish.csv"
fishes = pd.read_csv(filename2, sep=',', header=None, index_col=False)

# Perform the necessary imports
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt

# Create scaler: scaler
scaler = StandardScaler()

# Create a PCA instance: pca
pca = PCA()

# Create pipeline: pipeline
pipeline = make_pipeline(scaler, pca)

# Fit the pipeline to 'samples'
pipeline.fit(fishes.iloc[:,1:])

# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()

# %% [markdown]
# Refaire la PCA, en se limitant avec 2 composantes (attention, cette fois-ci, les fishes ont été "scalé")

# %%
# Import PCA
from sklearn.decomposition import PCA

# Create a PCA model with 2 components: pca
pca = PCA(n_components=2)

# Fit the PCA instance to the scaled samples
pca.fit(scaled_samples)

# Transform the scaled samples: pca_features
pca_features = pca.transform(scaled_samples)

# Print the shape of pca_features
print(pca_features.shape)
